# %% [markdown]
# #### 1. How should a model be selected for machine learning? Briefly discuss the steps.
#
# 1. choosing suitable algortihm
# 2.  observing the performance
# 3. minimizing the errors
# 4. optimizing the models

# %% [markdown]
# #### What is meant by error criteria in machine learning? Classify different error criteria and mention their usage.
#
# Error criteria is method of detecting error of a model. It is required in machin learning to evaluate model performance.
# There is different kind of error criteria
#  - MSE
#  - RMSE
#  - MAPE
#  - MAE
#  - Huber loss
#  - Cross Entropy loss
#  - Hinge Loss
#
#  In the presence of outliers MSE and RMSE cirteria should be avoided because they are sensitive outliers. Insted of them MAPE or MAE should be
#  used. Huber loss is upgrade version of RMSE/MSE. Huber loss isn't sensitive to outliers.
#
# ![Huberr Loss Eqn](attachment:Capture4.PNG)

# %% [markdown]
# ### 3. What is determined by distance metrics in machine learning? Mention different distance metrics and their usage.
#
# Distance metrics are used in machine laearning for determining the closeness of ttwo data points. If distance of two data point is very then
# we can say that those data points are belong to same class
# - Eucledian distance
# - Manhattan distance
# - Cosine distance
# - Chebysev distance
# - minkowaski distance

# %% [markdown]
# ### 4. What are parameters and hyperparameters in machine learning? Mention and briefly explain some hyperparameter tuning techniques.
#
# Paremeter
# : What is is learned in machine learning model is called parameters. These are internal to ML model. Like in the case of
#
#     1.Neural netwrok
#      - Weights
#      - Biase
#     2.Regression Models
#       -linear coeficient
#       -logistic regression coefficient
#     3.clustered algorithom
#         - cluster centoroids
#
# hyperparameters
# : Hyperparameters are external to the model. ML algorithms are depend on Hyperparametes. Hyperparameters valuse are set before model training
# like batch size, pooling, number of layers, epochs, number of iterations etc.
